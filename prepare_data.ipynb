# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd /content/drive/MyDrive/thesis-relation-extraction-vn
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive/thesis-relation-extraction-vn

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
# !pip install py_vncorenlp
# Out:
# Requirement already satisfied: py_vncorenlp in /usr/local/lib/python3.10/dist-packages (0.1.4)
# Requirement already satisfied: pyjnius in /usr/local/lib/python3.10/dist-packages (from py_vncorenlp) (1.6.1)

# %%
# %cd /content/drive/MyDrive/thesis-relation-extraction-vn
# Out:
# /content/drive/MyDrive/thesis-relation-extraction-vn

# %%
! python3 generate_features.py
# Out:
# 2023-12-01 05:33:24 INFO  WordSegmenter:24 - Loading Word Segmentation model
# 2023-12-01 05:33:24 INFO  PosTagger:23 - Loading POS Tagging model
# 2023-12-01 05:33:31 INFO  NerRecognizer:34 - Loading NER model
# 2023-12-01 05:34:10 INFO  DependencyParser:32 - Loading Dependency Parsing model
# TRY keep entity mark when tokenize for
# Chất tan được đặt bên trong cốc thủy tinh và 5 mL <e1>dung môi</e1> được dùng pipet hút vào <e2>bình</e2> thủy tinh 25 mL cho mỗi thử nghiệm.
# TRY keep entity mark when tokenize for
# <e1>Tòa án</e1> đã quyết định phản đối bằng cách đưa ra <e2>lệnh trả góp</e2> như yêu cầu.
# TRY keep entity mark when tokenize for
# <e1>Người lái xe</e1> của xe tải chở xi măng đã làm sạch máng xếp hàng trên xe tải của mình bằng một <e2>vòi</e2> nước gắn trên xe tải và bắt đầu lao đi.
# TRY keep entity mark when tokenize for
# Kế hoạch Marshall cũng cung cấp một cách để đạt được sự chấp nhận của công chúng ở châu Âu đối với định dạng Thỏa thuận mới mà Hoa Kỳ đã sử dụng thành công trước chiến tranh để chấm dứt <e1>suy thoái kinh tế</e1> do <e2>sụp đổ< ở Phố Wall năm 1929 gây ra /e2>.
# SKIP for
# Kế hoạch Marshall cũng cung cấp một cách để đạt được sự chấp nhận của công chúng ở châu Âu đối với định dạng Thỏa thuận mới mà Hoa Kỳ đã sử dụng thành công trước chiến tranh để chấm dứt <e1>suy thoái kinh tế</e1> do <e2>sụp đổ< ở Phố Wall năm 1929 gây ra /e2>.
# TRY keep entity mark when tokenize for
# <e1>hình học</e1> tổng thể của tim được trích xuất từ ​​<e2>dữ liệu</e2> cường độ.
# SKIP for
# <e1>hình học</e1> tổng thể của tim được trích xuất từ ​​<e2>dữ liệu</e2> cường độ.
# TRY keep entity mark when tokenize for
# Anh ấy đã lên lịch lại <e1>bữa tiệc</e1> sinh nhật sang <e2>ngày hôm sau</e2>.
# TRY keep entity mark when tokenize for
# Đối với những người không chắc tiếng Afrikaans là gì, đó là ngôn ngữ có nguồn gốc từ người Hà Lan, những người định cư đầu tiên ở Nam Phi và <e1>ngôn ngữ</e1> duy nhất được phát triển từ <e2>những người định cư</e2 khác > từ Malaya, Indonesia, Madagascar và Tây Phi.
# SKIP for
# Đối với những người không chắc tiếng Afrikaans là gì, đó là ngôn ngữ có nguồn gốc từ người Hà Lan, những người định cư đầu tiên ở Nam Phi và <e1>ngôn ngữ</e1> duy nhất được phát triển từ <e2>những người định cư</e2 khác > từ Malaya, Indonesia, Madagascar và Tây Phi.
# TRY keep entity mark when tokenize for
# Ông bà tôi yên nghỉ bên dưới một phiến đá có hình <e1>người nông dân</e1> đang cày với một con <e2>con la</e2>, một biểu tượng về cách họ bắt đầu cuộc sống cùng nhau từ những năm 1930.
# TRY keep entity mark when tokenize for
# Một trường hợp <e1>u sọ hầu</e1> bắt nguồn từ <e2>xương</e2> xương bướm được trình bày.
# TRY keep entity mark when tokenize for
# Các <e1>nhịp</e1> cong của <e2>cầu</e2> là phần ban đầu.
# TRY keep entity mark when tokenize for
# Các nhà khoa học gần đây đã thành công trong việc xóa sạch một <e1>ký ức</e1> khó chịu khỏi tâm trí của một <e2>chuột</e2> biến đổi gen.
# SKIP for
# Các nhà khoa học gần đây đã thành công trong việc xóa sạch một <e1>ký ức</e1> khó chịu khỏi tâm trí của một <e2>chuột</e2> biến đổi gen.
# TRY keep entity mark when tokenize for
# Vụ giết người đã kéo <e1>nạn nhân</e1> xuống <e2>nước</e2>.
# TRY keep entity mark when tokenize for
# Đây là <e1>kênh</e1> truyền hình cáp đặc biệt chiếu <e2>thể thao</e2> và các chương trình liên quan đến thể thao.
# TRY keep entity mark when tokenize for
# <e1>thiết bị</e1> hiển thị trong <e2>hình</e2> xoay.
# TRY keep entity mark when tokenize for
# <e1>Cánh buồm</e1> có một <e2>con gián</e2> quan trọng và có các khớp nối có thể điều chỉnh được trên các ngăn chứa đỉa và luff.
# TRY keep entity mark when tokenize for
# <e1>Tên</e1> của tín hiệu chiến đấu cao trào, Neodammerung có nguồn gốc từ <e2>từ</e2> Gotterdammerung trong tiếng Đức, nghĩa đen là hoàng hôn của các vị thần.
# TRY keep entity mark when tokenize for
# Lò phản ứng <e1>tan chảy</e1> đã gây ra một <e2>phản ứng</e2> dây chuyền phá hủy tất cả các tòa tháp trong mạng lưới.
# TRY keep entity mark when tokenize for
# Có một câu nói của Sickert khi anh ấy nói ở đâu đó về một điều gì đó thành công giống như <e1>trang</e1> bị xé ra từ <e2>cuốn sách</e2> của cuộc đời.
# TRY keep entity mark when tokenize for
# Thành phố này có <e1>số dân</e1> <e2>cư dân</e2> khu ổ chuột cao thứ tư trong số các thành phố lớn ở Ấn Độ.
# TRY keep entity mark when tokenize for
# <e1>Chàng trai</e1> trẻ tuổi ngắm tuyết qua <e2>cửa sổ</e2> và anh ấy muốn ở lại quán cà phê đó mãi mãi.
# TRY keep entity mark when tokenize for
# Trong khuôn khổ của cách tiếp cận toàn diện để hỗ trợ và phát triển sinh viên, Dịch vụ Sinh viên cũng là điểm liên lạc cho các chức năng khác như sự tham gia của sinh viên ngoài lớp học, sự tham gia của <e1>sinh viên</e1> trong <e2>quản trị trường đại học< /e2> cũng như trong Hội sinh viên.
# SKIP for
# Trong khuôn khổ của cách tiếp cận toàn diện để hỗ trợ và phát triển sinh viên, Dịch vụ Sinh viên cũng là điểm liên lạc cho các chức năng khác như sự tham gia của sinh viên ngoài lớp học, sự tham gia của <e1>sinh viên</e1> trong <e2>quản trị trường đại học< /e2> cũng như trong Hội sinh viên.
# TRY keep entity mark when tokenize for
# Linh dương <e1>sừng</e1> mọc từ sa mạc Nam California <e2>núi</e2> băng qua Arkansas và lên tận Kansas.
# TRY keep entity mark when tokenize for
# Sự phục hồi sau <e1>khủng hoảng</e1> kinh tế toàn cầu do <e2>sự sụp đổ</e2> của Lehman Brothers gây ra đã đạt được nhờ sự hợp tác từ Brazil, Nga, Ấn Độ và Trung Quốc.
# TRY keep entity mark when tokenize for
# Quy trình Mê cung tạo ra các đường dẫn mới cho <e1>các xung</e1> điện kích hoạt <e2>nhịp tim</e2>.
# TRY keep entity mark when tokenize for
# Anh <e1>quân</e1> đã thực hiện <e2>xâm nhập</e2> sâu nhất vào Basra ngày hôm qua, chọc thủng một ngón chân trong vòng bốn dặm từ trung tâm.
# TRY keep entity mark when tokenize for
# Một <e1>đồng xu</e1> bạc duy nhất được thu thập từ <e2>ấm đun nước</e2> màu đỏ của Salvation Army gần Berlin không chỉ là một giọt nước khác trong thùng.
# TRY keep entity mark when tokenize for
# Cuba đã là một khách hàng và hiện nay ngân hàng phát triển nhà nước, BNDES, có kế hoạch tài trợ cho việc xuất khẩu bí quyết sản xuất ethanol sang châu Phi, nơi hy vọng của các quốc gia như Ghana được đặt vào nhà máy <e1>jatropha</e1> <e2>< /e2>.
# SKIP for
# Cuba đã là một khách hàng và hiện nay ngân hàng phát triển nhà nước, BNDES, có kế hoạch tài trợ cho việc xuất khẩu bí quyết sản xuất ethanol sang châu Phi, nơi hy vọng của các quốc gia như Ghana được đặt vào nhà máy <e1>jatropha</e1> <e2>< /e2>.
# TRY keep entity mark when tokenize for
# Và đó là lý do tại sao chúng tôi thậm chí còn tự hào hơn khi thông báo rằng lời kêu gọi - nhờ lòng hảo tâm của độc giả - đã quyên góp được 26.000 bảng Anh, bất chấp <e1>khó khăn</e1> do <e2>suy thoái kinh tế</e2 gây ra >.
# SKIP for
# Và đó là lý do tại sao chúng tôi thậm chí còn tự hào hơn khi thông báo rằng lời kêu gọi - nhờ lòng hảo tâm của độc giả - đã quyên góp được 26.000 bảng Anh, bất chấp <e1>khó khăn</e1> do <e2>suy thoái kinh tế</e2 gây ra >.
# TRY keep entity mark when tokenize for
# Và <e1>khủng hoảng</e1> kinh tế được tạo ra do <e2>lộn xộn</e2> thế chấp dưới chuẩn gây ra thông qua sự can thiệp của chính phủ vào thị trường để thúc đẩy các lý tưởng tiến bộ (nghĩa là mở rộng các khoản vay cho những người đi vay có thu nhập thấp) .
# TRY keep entity mark when tokenize for
# Hoạt hình <e1>bài tập</e1> của tôi từ <e2>học kỳ</e2> trước đã khiến mọi người mỉm cười.
# TRY keep entity mark when tokenize for
# <e1>Sự biến dạng</e1> là do <e2>tương tác</e2> lực hấp dẫn với các vệ tinh nhỏ Prometheus và Pandora.
# TRY keep entity mark when tokenize for
# Việc <e1>thêm</e1> nước vào bể gây ra <e2>phản ứng</e2> hóa học, dẫn đến áp suất và nhiệt độ tăng nhanh.
# TRY keep entity mark when tokenize for
# Việc kích hoạt quá trình chuyển đổi T_continuous_call thể hiện sự xuất hiện của một <e1>cuộc gọi</e1> chuyển giao từ các <e2>ô</e2> lân cận.
# TRY keep entity mark when tokenize for
# <e1>Quy tắc</e1> là chủ đề của <e2>thách thức pháp lý</e2> do ABC và các đối tác liên minh đưa ra.
# TRY keep entity mark when tokenize for
# Nó là một phần của <e1>dòng sản phẩm</e1> nội thất do các nhà <e2>nhà thiết kế</e2> nội thất người Anh hình thành cho Anthropologie.
# TRY keep entity mark when tokenize for
# <e1>stent</e1> hình chữ Z bằng thép được làm bằng một <e2>dây</e2> dẫn hướng bằng thép (đường kính 0,2 mm), được phủ bằng mảnh ghép mạch máu và được cố định vào thành mảnh ghép bằng nhiều mũi khâu đứt đoạn. .
# TRY keep entity mark when tokenize for
# Trong số những người Hittite chỉ có một hoàng hậu, nhưng nhà vua có <e1>hậu cung</e1> gồm <e2>những người vợ</e2> (phụ nữ tự do) và cả những phi tần nô lệ.
# TRY keep entity mark when tokenize for
# Tín hiệu <e1>RF</e1>RF 100 MHz</e1> cho bộ điều chế biên độ được lấy từ một <e2>bộ tạo</e2> mẫu xung (PPG).
# TRY keep entity mark when tokenize for
# Cũng bị mất tích là một khẩu súng <e1>Súng</e1> Smith & Wesson cỡ nòng 38 nằm trong <e2>va li</e2> trên máy kéo.
# TRY keep entity mark when tokenize for
# Theo luật, <e1>hóa đơn</e1> <e2>chi tiết</e2> là danh sách các tuyên bố bằng văn bản do một bên đưa ra trong thủ tục tố tụng tại tòa án, theo yêu cầu của một bên khác, đưa ra các chi tiết của khiếu nại hoặc phòng thủ.
# TRY keep entity mark when tokenize for
# <e1>Kem</e1> đá được làm bằng <e2>tay</e2> trong một cái bát lớn đặt bên trong bồn chứa đầy đá và muối.
# TRY keep entity mark when tokenize for
# Tôi đã đặt trực tiếp một <e1>thẻ nhớ</e1> mới vào <e2>điện thoại</e2> di động của mình.
# TRY keep entity mark when tokenize for
# Một <e1>rổ</e1> như bạn đề cập chứa bốn <e2>bắp</e2> ngô.
# TRY keep entity mark when tokenize for
# <e1>Lò</e1> Banko được thành lập bởi <e2>thợ gốm</e2> Nunami Ro-zan (1718-77), người thường bắt chước công việc của Kenzan (1663-1743).
# TRY keep entity mark when tokenize for
# Trong 25 năm, Giáng sinh ở New Bern đã bao gồm một <e1>đội tàu</e1> <e2>thuyền</e2> được trang trí lướt dọc theo ngã ba sông Neuse và sông Trent tại Công viên Union Point.
# TRY keep entity mark when tokenize for
# Các quan chức đã nhận được cảnh báo từ con trai của nạn nhân: người cha 87 tuổi của anh ta là một người tích trữ và <e1>ngôi nhà</e1> chứa đầy <e2>đồ vật</e2>.
# TRY keep entity mark when tokenize for
# Một <e1>nông dân</e1> đã dựng lên <e2>lớp ngụy trang</e2> vào năm 2000 từ hàng trăm kiện rơm có kích thước 8 ftx4 ft và phủ bạt xanh lên trên.
# TRY keep entity mark when tokenize for
# <e1>van</e1> an toàn của <e2>bể</e2> đầu tiên được kích hoạt sau 16 phút 27 giây, trong khi van an toàn của bể thứ hai được kích hoạt sau 16 phút 53 giây.
# TRY keep entity mark when tokenize for
# Một <e1>người nông dân</e1> cởi trần cật lực cày đất bằng <e2>máy xới tay</e2> trong khi người vợ của anh ta lặng lẽ mang theo hạt giống cho đất mới trở nên tươi tốt.
# TRY keep entity mark when tokenize for
# Thermocerin là một chất <e1>đốt cháy</e1> chất béo hiệu quả hoạt động với sự kết hợp của <e2>thảo dược</e2> tự nhiên như Trà trắng và Trà xanh, Capsaicin và Caffeine.
# TRY keep entity mark when tokenize for
# <e1>Tỷ phú</e1> tạo nên <e2>danh sách người giàu</e2> của Ấn Độ.
# TRY keep entity mark when tokenize for
# Bàn tay vô hình, còn được gọi là bàn tay vô hình của thị trường, là một <e1>phép ẩn dụ</e1> do <e2>nhà kinh tế học</e2> đặt ra lần đầu tiên trong Lý thuyết về tình cảm đạo đức.
# TRY keep entity mark when tokenize for
# Chỉ báo quay số được gắn trên <e1>trục quay</e1> của <e2>máy</e2> phay.
# TRY keep entity mark when tokenize for
# Củ chín được nghiền bằng máy để làm <e1>mít</e1> <e2>mật hoa</e2> hoặc giảm thành chất cô đặc hoặc bột.
# TRY keep entity mark when tokenize for
# Đã xem xét các báo cáo <e1>kiểm toán</e1> về kiểm toán hợp đồng <e2>quản lý</e2> do Văn phòng Tổng Thanh tra NASA và Văn phòng Tổng Kế toán Hoa Kỳ ban hành.
# TRY keep entity mark when tokenize for
# <e1>Việc ngược đãi</e1> bắt nguồn từ <e2>bệnh</e2> tâm thần của thủ phạm.
# TRY keep entity mark when tokenize for
# <e1>Đậu phụ</e1> (to-fu), hay đậu phụ là một loại thực phẩm mềm màu trắng được làm bằng cách làm đông tụ <e2>sữa</e2> đậu nành.
# TRY keep entity mark when tokenize for
# Những người trong số các bạn đã chạy tự do, tôi hy vọng sẽ săn lùng được các bạn, để đặt một đàn chó săn của Thiên đường hay Địa ngục, tùy theo số phận của tôi, trên một <e1>rangale</e1> lớn màu đỏ <e2>hươu</e2 >, hoặc chính tay tôi cầm cung nỏ đâm thủng tim lợn rừng, rồi ngồi vào bàn xé thịt ngọt ngào của bạn mà ăn.
# SKIP for
# Những người trong số các bạn đã chạy tự do, tôi hy vọng sẽ săn lùng được các bạn, để đặt một đàn chó săn của Thiên đường hay Địa ngục, tùy theo số phận của tôi, trên một <e1>rangale</e1> lớn màu đỏ <e2>hươu</e2 >, hoặc chính tay tôi cầm cung nỏ đâm thủng tim lợn rừng, rồi ngồi vào bàn xé thịt ngọt ngào của bạn mà ăn.
# TRY keep entity mark when tokenize for
# Một <e1>chỉ số</e1> về mức độ phù hợp với môi trường sống được tạo ra từ một <e2>bề mặt</e2> độ cao.
# TRY keep entity mark when tokenize for
# Nhìn từ một phía, <e1>bức tường</e1> bao quanh một <e2>cánh đồng</e2> rộng 60 mẫu Anh được gọi là Cảng Anarres.
# TRY keep entity mark when tokenize for
# <e1>Cơn đau</e1> mà anh ấy cảm thấy là do cái cây <e2>cọ xát</e2> vào các mao mạch của anh ấy.
# TRY keep entity mark when tokenize for
# Họ đã sử dụng <e1>xếp hạng</e1> uy tín thu được từ <e2>trưởng khoa</e2> học thuật, nhà tuyển dụng tại các công ty và các ứng viên MBA tiềm năng.
# TRY keep entity mark when tokenize for
# <e1>Máu</e1> bắt nguồn từ một <e2>mạch máu</e2> bất thường bị rò rỉ hoặc vỡ.
# TRY keep entity mark when tokenize for
# Luận án này xem xét bốn <e1>chuyện tình</e1> do chính người <e2>người ghi chép</e2> sao chép.
# TRY keep entity mark when tokenize for
# <e1>Lính cứu hỏa</e1> đánh dấu các vòi chữa cháy hoạt động tốt bằng cách phun <e2>sơn</e2>.
# TRY keep entity mark when tokenize for
# Trong tiếng Swahili, Jana có nghĩa là ngày hôm qua; vì vậy đây là một số <e1>mục</e1> từ <e2>hôm qua</e2> của cô ấy.
# TRY keep entity mark when tokenize for
# Một <e1>thuyền</e1> buồm có <e2>cánh buồm chính</e2> lớn, một cánh buồm trước nhỏ hơn và có lẽ là một con quay lớn giống như quả bóng bay ở phía trước.
# TRY keep entity mark when tokenize for
# Mặt trời trưng bày một <e1>thiết kế</e1> của một con khỉ <e2>khỉ</e2>.
# SKIP for
# Mặt trời trưng bày một <e1>thiết kế</e1> của một con khỉ <e2>khỉ</e2>.
# TRY keep entity mark when tokenize for
# Ấn Độ có kế hoạch xây dựng một <e1>chòm sao</e1> gồm bảy <e2>vệ tinh</e2> địa tĩnh với chi phí 1.600 Rs crore để đáp ứng các yêu cầu về hệ thống định vị trong ô tô, tàu hỏa và máy bay.
# TRY keep entity mark when tokenize for
# Hai ngày sau, <e1>con cá</e1> nước mặn được thả vào một con <e2>pao</e2> nước ngọt.
# TRY keep entity mark when tokenize for
# Toàn bộ một phần tư <e1>sản phẩm</e1> trong <e2>siêu thị</e2> có một số dạng ngô trong đó.
# TRY keep entity mark when tokenize for
# <e1>Vết đốt</e1> hoặc vết cắn là do muỗi vằn, ruồi ngựa, ong, <e2>ong bắp cày</e2>, kiến, một số loài nhện, bọ chét, rận, v.v.
# TRY keep entity mark when tokenize for
# Trên chiếc ghế trong phòng ngủ và dọc theo <e1>thanh vịn</e1> của <e2>giường</e2> nằm rải rác những bộ quần áo, những bộ quần áo duy nhất mà anh biết cho đến nay, và những miếng băng của vị khách của họ.
# TRY keep entity mark when tokenize for
# Đội trưởng Younis Khan của Pakistan hôm thứ Năm đã buộc phải bỏ qua một phiên thảo luận truyền thông đã được lên lịch trước trong thành phố sau khi bị một <e1>đầu</e1> đàn <e2>ong</e2> mật cắn bên ngoài nhà của anh ấy.
# TRY keep entity mark when tokenize for
# <e1>Thiết bị</e1> trang trại này sử dụng động cơ <e2>diesel</e2> làm mát bằng không khí, rất phù hợp với những nơi thiếu nước hoặc khó lấy nước.
# TRY keep entity mark when tokenize for
# Trong một tin tức khác, một <e1>mèo con</e1> trẻ và đã chết đã trốn khỏi <e2>phòng</e2> thẩm vấn vào khoảng 3 giờ sáng nay.
# TRY keep entity mark when tokenize for
# Ông thành lập Chương trình Emmaus, một <e1>triệu tập</e1> hàng năm của <e2>giáo sĩ</e2> giáo phận để tiếp tục giáo dục và đào tạo tâm linh, vào năm 1983.
# TRY keep entity mark when tokenize for
# Giá <e1>mía</e1> <e2>đường</e2> cao hơn dường như không có bất kỳ tác động nào đến giá nước giải khát.
# TRY keep entity mark when tokenize for
# Một <e1>người đàn ông</e1> địa phương đã dựng một <e2>tượng đài</e2> tại địa điểm này và vào năm 1997, một nhóm cộng đồng đã dựng một tấm biển chào đón du khách.
# TRY keep entity mark when tokenize for
# Tim, <e1>mạch máu</e1>, máu là các bộ phận của <e2>hệ thống tuần hoàn</e2>.
# TRY keep entity mark when tokenize for
# <e1>Phương pháp</e1> này làm tăng hiệu suất của tàu thông qua việc <e2>giảm thiểu</e2> lực cản, đồng thời bảo vệ đại dương khỏi các chất diệt khuẩn có thể bị rò rỉ.
# TRY keep entity mark when tokenize for
# Pam Court đã thêm vào <e1>cuộc tranh luận</e1> chỉ ra <e2>nhu cầu</e2> đầu tư vào dịch vụ chăm sóc chính như một phần của chiến lược dài hạn.
# TRY keep entity mark when tokenize for
# Di căn từ buồng trứng và tử cung được nhìn thấy ở <e1>da</e1> của <e2>bụng</e2> dưới, háng hoặc đùi trên.
# TRY keep entity mark when tokenize for
# Nạn nhân bị trượt khỏi cầu tàu khi cố gắng đóng <e1>nắp</e1> của <e2>thùng</e2> xe moóc.
# TRY keep entity mark when tokenize for
# Công ty đã kéo <e1>bộ giảm tốc</e1> vào <e2>hệ thống</e2> vận chuyển hydrocacbon.
# TRY keep entity mark when tokenize for
# Nhưng không điều nào trong số này thực sự cần thiết, bởi vì bạn chỉ hướng đến <e1>tòa nhà</e1> lớn nhất từng được tạo ra bởi <e2>con người</e2>.
# TRY keep entity mark when tokenize for
# Nhà <e1>nhà phát minh</e1> kỳ cựu nổi tiếng với việc tạo ra <e2>đài phát thanh</e2> hoạt động bằng đồng hồ đang lên kế hoạch đưa công ty ươm tạo của mình lên Sàn giao dịch chứng khoán.
# TRY keep entity mark when tokenize for
# <e1>Dụng cụ phẳng</e1> khổ nặng bao gồm <e2>thép</e2> không gỉ được đánh bóng để có độ nặng và độ cân bằng tốt.
# TRY keep entity mark when tokenize for
# Tina Moeckel và Gail Coakley đã làm việc cho Hiệp hội được 17 năm, có con trai và con gái mà họ đã khiêu vũ trên sân khấu, làm việc ở hậu trường và thuộc về <e1>tình chị em</e1> của các nữ <e2>vũ công</e2 >, bây giờ là bạn suốt đời.
# SKIP for
# Tina Moeckel và Gail Coakley đã làm việc cho Hiệp hội được 17 năm, có con trai và con gái mà họ đã khiêu vũ trên sân khấu, làm việc ở hậu trường và thuộc về <e1>tình chị em</e1> của các nữ <e2>vũ công</e2 >, bây giờ là bạn suốt đời.
# TRY keep entity mark when tokenize for
# Trong các máy nén có động cơ pittông kín được biết đến, <e1>khí</e1> chất làm lạnh được bốc hơi từ trong <e2>vỏ</e2>.
# TRY keep entity mark when tokenize for
# Việc không thể tham dự với các hội tần tập trung ở nhiều vùng khác nhau của vương quốc, đã dẫn đến việc thuê những người thuyết trình không lâu sau đó; và đến lượt những người này dần dần nhường chỗ cho một <e1>thứ tự</e1> đã được thiết lập gồm những người <e2>nhà truyền đạo</e2> lưu động; và sau đó, những điều này trở lại với các bộ trưởng được giải quyết trong một thời gian giới hạn, với các giám mục giám sát.
# TRY keep entity mark when tokenize for
# Anh ấy chỉ mua <e1>lò</e1> vi sóng có <e2>cơ chế</e2> an toàn, ngắt điện khi cửa mở hoặc ngăn cửa mở khi lò đang hoạt động.
# TRY keep entity mark when tokenize for
# Mứt lê và gừng gừng được làm từ <e1>dư</e1> <e2>lê</e2> corella.
# SKIP for
# Mứt lê và gừng gừng được làm từ <e1>dư</e1> <e2>lê</e2> corella.
# TRY keep entity mark when tokenize for
# Họ đã giới thiệu <e1>micrô</e1> tiếp xúc áp điện thụ động bằng đồng thau với <e2>phích cắm</e2> đầu ra 1/4 đực chất lượng cao.
# TRY keep entity mark when tokenize for
# Cảnh sát trưởng <e1>New Haven</e1> <e2></e2> James Lewis đã rời vị trí của mình sau khi hết hạn hợp đồng vào ngày 31 tháng 1.
# SKIP for
# Cảnh sát trưởng <e1>New Haven</e1> <e2></e2> James Lewis đã rời vị trí của mình sau khi hết hạn hợp đồng vào ngày 31 tháng 1.
# TRY keep entity mark when tokenize for
# <e1>tay nắm cửa</e1> <e2>tay nắm</e2> này có màu vàng và được lắp ở cửa trước.
# TRY keep entity mark when tokenize for
# Ngôi sao Bollywood nổi tiếng Koena Mitra trượt xuống đoạn đường dốc trong <e1>sáng tạo</e1> tuyệt đẹp của <e2>nhà thiết kế</e2>.
# TRY keep entity mark when tokenize for
# Một <e1>cách tiếp cận</e1> hợp lý đã được chắt lọc từ <e2>cú sốc</e2> ban đầu trước dữ liệu mâu thuẫn.
# TRY keep entity mark when tokenize for
# Câu chuyện về cuộc đấu tranh hoành tráng giữa Đế chế Hồi giáo Ottoman và Vương quốc Cơ đốc giáo ở Đông Âu được kể dưới góc nhìn của một hội anh em bí mật, Excubitors, một <e1>tình anh em</e1> của <e2>các cố vấn</e2 > cho các vị vua, sultan, người đứng đầu nhà thờ, hiệp sĩ, học giả, nhà tài chính và nhà thám hiểm thương gia, những người nắm giữ các vị trí có ảnh hưởng ở cả hai bên của cuộc xung đột.
# SKIP for
# Câu chuyện về cuộc đấu tranh hoành tráng giữa Đế chế Hồi giáo Ottoman và Vương quốc Cơ đốc giáo ở Đông Âu được kể dưới góc nhìn của một hội anh em bí mật, Excubitors, một <e1>tình anh em</e1> của <e2>các cố vấn</e2 > cho các vị vua, sultan, người đứng đầu nhà thờ, hiệp sĩ, học giả, nhà tài chính và nhà thám hiểm thương gia, những người nắm giữ các vị trí có ảnh hưởng ở cả hai bên của cuộc xung đột.
# TRY keep entity mark when tokenize for
# Để có những ý tưởng hữu ích khác về cách sử dụng văn bản điện tử để hỗ trợ phân tích văn học, các cô gái đã đọc <e1>máy tính</e1> cá nhân của Robert Harris như một công cụ để phân tích văn học cho <e2>học sinh</e2>.
# TRY keep entity mark when tokenize for
# Campbell, từ <e1>đảng nghị sĩ</e1> của chính <e2>đảng</e2> của <e1>, bước vào cuộc cạnh tranh, đưa ra một dự luật đặc biệt tạo ra ngoại lệ đối với quy tắc chung trong trường hợp cụ thể của học sinh, Jesus Apodaca.
# SKIP for
# Campbell, từ <e1>đảng nghị sĩ</e1> của chính <e2>đảng</e2> của <e1>, bước vào cuộc cạnh tranh, đưa ra một dự luật đặc biệt tạo ra ngoại lệ đối với quy tắc chung trong trường hợp cụ thể của học sinh, Jesus Apodaca.
# TRY keep entity mark when tokenize for
# <e1>da</e1> gà được nấu chín bên trong <e2>bình</e2> sau khi được nhồi thịt của chính nó.
# TRY keep entity mark when tokenize for
# Chúng là <e1>bầy</e1> <e2>trẻ khóc nhè</e2> lớn nhất mà tôi từng tiếp xúc trong 30 năm ở Washington.
# TRY keep entity mark when tokenize for
# Tôi đã tháo và lắp lại <e1>tay nắm cửa</e1> <e2>tay cầm</e2> của mình để xem liệu có thể thực hiện tất cả các thao tác này bên ngoài cửa hay không.
# TRY keep entity mark when tokenize for
# Một <e1>cô bé</e1> nhỏ bước ra từ <e2>tủ quần áo</e2>, mặt sưng đỏ vì khóc.
# TRY keep entity mark when tokenize for
# Bạn tìm thấy một <e1>chai</e1> có <e2>nước</e2> màu xanh lam xinh xắn trong phòng tắm.
# TRY keep entity mark when tokenize for
# Cắn miếng phi lê cá hồi Copper River có thịt nướng cháy thành than nằm trên <e1>đồi</e1> của <e2>đậu</e2> xanh mềm giòn và khoai tây bỏ lò -- một giọt giấm mù tạt xung quanh đĩa rim nước sốt duy nhất nó muốn -- Tôi đã trở lại San Francisco một lần nữa.
# TRY keep entity mark when tokenize for
# <e1>Ví dụ</e1> thứ hai là về <e2>hàm</e2> cấp phát bộ nhớ.
# TRY keep entity mark when tokenize for
# <e1>Vụ kiện</e1> cáo buộc việc tiết lộ hồ sơ là một <e2>vi phạm</e2> Đạo luật bảo vệ quyền riêng tư video.
# SKIP for
# <e1>Vụ kiện</e1> cáo buộc việc tiết lộ hồ sơ là một <e2>vi phạm</e2> Đạo luật bảo vệ quyền riêng tư video.
# TRY keep entity mark when tokenize for
# <e1>Cảnh tượng</e1> đau lòng đã được tường thuật trong nhiều tuần trên các <e2>báo</e2> quốc gia.
# TRY keep entity mark when tokenize for
# <e1>Cơ quan quản lý</e1> của công ty đã bị kéo vào <e2>cuộc điều tra</e2> của người đảm nhận.
# TRY keep entity mark when tokenize for
# Những người bản địa trước khi tiếp xúc, sống ở phía đông bắc của Bắc Mỹ, là những người <e1>người</e1> đầu tiên sản xuất xi-rô cây phong và <e2>đường</e2> cây phong.
# TRY keep entity mark when tokenize for
# Những <e1>cà nhà</e1> lớn của <e2>gà tây</e2> đã bị chết đuối khi đứng dưới mưa, ngước nhìn nó với cái miệng há hốc.
# TRY keep entity mark when tokenize for
# Một người phụ nữ bị buộc tội ném <e1>bàn</e1> <e2>chân</e2> qua cửa sổ nhà sau khi bạn trai của cô ấy từ chối mua thêm bia sẽ phải đối mặt với tội nghiêm trọng.
# TRY keep entity mark when tokenize for
# <e1>tên</e1> bắt nguồn từ <e2>từ</e2> tiếng Hà Lan hoặc tiếng Flemish.
# TRY keep entity mark when tokenize for
# <e1>Công ty</e1> của chúng tôi chuyển đổi nhựa thải thành <e2>dầu</e2> thô.
# TRY keep entity mark when tokenize for
# <e1>Người đàn ông</e1> 71 tuổi đã biến một căn phòng ở tầng hầm thành <e2>văn phòng</e2>.
# TRY keep entity mark when tokenize for
# <e1>Phản ứng</e1> hóa học trong nước gây ra <e2>hiệu ứng</e2> sủi bọt trên bề mặt.
# TRY keep entity mark when tokenize for
# <e1>Kết quả kiểm tra</e1> được nhập vào <e2>sổ nhật ký</e2> điện tử.
# TRY keep entity mark when tokenize for
# Các học sinh cuối cấp đổ <e1>bột mì</e1> vào <e2>giấy</e2> sáp và ném các vật phẩm dưới dạng đạn vào các học sinh năm nhất trong một cuộc biểu tình động viên buổi sáng.
# TRY keep entity mark when tokenize for
# Những <e1>phòng thu</e1> này đã trở thành những xưởng sản xuất thành công thực sự đã sản xuất ra nhiều <e2>bản thu âm</e2> nhạc pop thành công nhất của thế kỷ 20 sau này.
# TRY keep entity mark when tokenize for
# Con <e1>con cái</e1> trưởng thành có <e2>cổ áo</e2> màu xanh ngọc lục bảo nhạt rất khó phân biệt trên thực địa.
# TRY keep entity mark when tokenize for
# <e1>Máy</e1> X-quang cụ thể này có một <e2>bộ hẹn giờ</e2> trên đó mà họ sử dụng cho thời gian phơi sáng.
# TRY keep entity mark when tokenize for
# <e1>Máy</e1> MRI đo phản hồi bằng <e2>máy tính</e2>.
# TRY keep entity mark when tokenize for
# <e1>Khả năng ứng dụng</e1> có giới hạn của Perceptron phát sinh từ <e2>tính tuyến tính</e2> của quy tắc quyết định có thể sửa đổi của nó.
# TRY keep entity mark when tokenize for
# Đặc biệt, chúng tôi đã bỏ lỡ cách <e1>âm nhạc</e1> trở thành một phần của <e2>văn hóa</e2> hàng ngày ở Hà Lan.
# TRY keep entity mark when tokenize for
# Một <e1>cuốn sách</e1> có tựa đề Heures de Louis le Grand nhìn vào <e2>cuộc đời</e2> và nghệ thuật của Vua Mặt trời được trưng bày tại triển lãm.
# TRY keep entity mark when tokenize for
# Tuy nhiên, sau năm 1646, sự nhấn mạnh của Thanh giáo đối với chủ nghĩa cá nhân và lương tâm cá nhân khiến phong trào này không thể thành lập một nhà thờ Trưởng lão quốc gia, và đến năm 1662, khi nhà thờ Anh giáo được tái lập, Thanh giáo đã trở thành một <e1>liên minh lỏng lẻo. /e1> của nhiều <e2>giáo phái</e2> Bất đồng chính kiến.
# SKIP for
# Tuy nhiên, sau năm 1646, sự nhấn mạnh của Thanh giáo đối với chủ nghĩa cá nhân và lương tâm cá nhân khiến phong trào này không thể thành lập một nhà thờ Trưởng lão quốc gia, và đến năm 1662, khi nhà thờ Anh giáo được tái lập, Thanh giáo đã trở thành một <e1>liên minh lỏng lẻo. /e1> của nhiều <e2>giáo phái</e2> Bất đồng chính kiến.
# TRY keep entity mark when tokenize for
# <e1>Tài liệu</e1> này đóng góp đáng kể vào việc <e2>làm rõ</e2> hơn nữa quyền tiếp cận nước uống như một quyền của con người.
# TRY keep entity mark when tokenize for
# Hình ảnh ở trên cùng cho thấy một <e1>nông dân</e1> với một <e2>cây</e2> bông biến đổi gen ở Nam Phi vào năm 2003.
# SKIP for
# Hình ảnh ở trên cùng cho thấy một <e1>nông dân</e1> với một <e2>cây</e2> bông biến đổi gen ở Nam Phi vào năm 2003.
# TRY keep entity mark when tokenize for
# OPM và những tổ chức khác thường phàn nàn về việc SES không thể tạo ra <e1>quân đoàn</e1> các <e2>các nhà điều hành</e2> nói chung - và đã thường xuyên đề nghị loại bỏ khỏi SES các giám đốc điều hành có kỹ năng kỹ thuật hoặc chuyên môn và năng lực.
# TRY keep entity mark when tokenize for
# <e1>Kích ứng</e1> từ <e2>hóa chất</e2> trong thuốc lá được coi là yếu tố góp phần số một.
# TRY keep entity mark when tokenize for
# Năm 1999, <e1>nhà tư vấn</e1> người Anh đã nghĩ ra một <e2>cách</e2> sáng tạo để xử lý giấy vụn.
# TRY keep entity mark when tokenize for
# Ban đầu, thành phần bộ binh của Lực lượng Vệ binh bao gồm một <e1>trung đoàn</e1> bộ binh <e2>lính bắn lựu đạn</e2> và một bộ binh bộ binh, mỗi bộ binh có hai tiểu đoàn hành quân và một tiểu đoàn huấn luyện.
# TRY keep entity mark when tokenize for
# Trong những trường hợp này, các cuộc hôn nhân được thực hiện trong <e1>ngôi đền</e1> bởi một người <e2>người niêm ấn</e2> trong đền thờ được ủy quyền hợp pháp sẽ được chính phủ công nhận.
# TRY keep entity mark when tokenize for
# Báo cáo xem xét quá khứ và tương lai của sự bùng nổ <e1>dân số</e1> của <e2>công dân</e2> cao tuổi.
# TRY keep entity mark when tokenize for
# Nhưng tôi đang cố lấy <e1>số</e1> một tuần từ một <e2>ngày</e2> nhất định.
# TRY keep entity mark when tokenize for
# <e1>Cơ quan</e1> cũng cung cấp một phần ba <e2>nguồn cung</e2> điện của khu vực, chủ yếu được lấy từ các máy phát điện bên trong các đập lớn.
# TRY keep entity mark when tokenize for
# <e1>ong</e1> thợ ăn <e2>mật ong</e2> thông thường chỉ sống được từ bốn đến sáu tuần.
# TRY keep entity mark when tokenize for
# <e1>Các dịch vụ</e1> này được di chuyển vào <e2>cuộc gọi</e2> vì chúng yêu cầu phương tiện đặt trước.
# TRY keep entity mark when tokenize for
# Những người trẻ tuổi từ Bridgend đã làm <e1>bộ phim</e1> hoạt hình này để làm nổi bật <e2>sự nguy hiểm</e2> của cháy rừng.
# TRY keep entity mark when tokenize for
# Người <e1>người đầy tớ</e1> mang ra <e2>đồ trang sức</e2> bằng bạc, đồ trang sức bằng vàng và quần áo, và đưa chúng cho Rebekah.
# TRY keep entity mark when tokenize for
# <e1>Tòa nhà</e1> chứa một lượng đáng kể <e2>đồ nội thất</e2> và thiết bị.
# TRY keep entity mark when tokenize for
# Các <e1>tông màu</e1> màu nâu và màu be nhẹ nhàng trong trang trí mang lại một <e2>tâm trạng</e2> yên tĩnh.
# SKIP for
# Các <e1>tông màu</e1> màu nâu và màu be nhẹ nhàng trong trang trí mang lại một <e2>tâm trạng</e2> yên tĩnh.
# TRY keep entity mark when tokenize for
# <e1>máy phát</e1> tạo ra <e2>sóng</e2> điện từ, một số sóng này sẽ tác động tới máy thu.
# TRY keep entity mark when tokenize for
# Arthur và Franz là những tên trộm, hoặc họ đang cố gắng trở thành những tên trộm, và bằng cách nào đó biết được rằng Odile sống trong một <e1>ngôi nhà</e1> chứa một lượng lớn <e2>tiền</e2>.
# TRY keep entity mark when tokenize for
# <e1>Nhiên liệu</e1> bị đốt cháy tạo ra <e2>khí</e2> thải ra, khi bị đẩy ra khỏi vòi sẽ tạo ra lực đẩy, di chuyển tên lửa theo hướng khác.
# TRY keep entity mark when tokenize for
# <e1>Thịt gà</e1> <e2>nước dùng</e2> có ba dạng khác nhau, dạng lỏng, dạng bột hoặc dạng khối.
# TRY keep entity mark when tokenize for
# Chà, <e1>cầu thủ bóng đá</e1> này đã đá <e2>quả bóng</e2> mạnh nhất có thể và đánh tôi.
# TRY keep entity mark when tokenize for
# <e1>dầu nành</e1> <e2>dầu</e2> thô đáp ứng các loại và tiêu chuẩn được sàn giao dịch chấp thuận - xem Quy tắc và Quy định của sàn giao dịch để biết thông số kỹ thuật chính xác.
# TRY keep entity mark when tokenize for
# <e1>Chất</e1> béo màu trắng thu được từ đầu cá nhà táng được sử dụng trong <e2>dược phẩm</e2> và nến.
# TRY keep entity mark when tokenize for
# Nằm gần đường xích đạo ở Nam Mỹ, <e1>cây ca cao</e1> sản xuất <e2>hạt ca cao</e2>, nguồn gốc của tất cả sô cô la.
# TRY keep entity mark when tokenize for
# Một <e1>hạt mưa</e1> giữ nguyên <e2>hình dạng</e2> ở mức gần đúng hợp lý trong suốt thời gian nó rơi xuống.
# TRY keep entity mark when tokenize for
# Điểm thu hút mới ít được biết đến hơn mà kibbutz mang lại là một <e1>dầu</e1> <e2>máy ép</e2> được xây dựng lại có nguồn gốc từ đầu thế kỷ 20 ở Jaffa.
# TRY keep entity mark when tokenize for
# Bao quanh mỗi tế bào thần kinh là một nhóm tế bào thuộc loại thần kinh đệm (tế bào vệ tinh), cùng với <e1>sợi</e1> collagen tạo thành <e2>viên thần kinh đệm</e2>.
# TRY keep entity mark when tokenize for
# Người châu Âu đã từ chối <e1>rượu vang</e1> được sản xuất từ ​​<e2>cây nho</e2> biến đổi gen, khiến những người trồng nho ở California, những người phụ thuộc nhiều vào thị trường châu Âu, lo lắng.
# SKIP for
# Người châu Âu đã từ chối <e1>rượu vang</e1> được sản xuất từ ​​<e2>cây nho</e2> biến đổi gen, khiến những người trồng nho ở California, những người phụ thuộc nhiều vào thị trường châu Âu, lo lắng.
# TRY keep entity mark when tokenize for
# Bằng cách sử dụng mô-đun kê đơn điện tử trong hệ thống hồ sơ điện tử, <e1>người kê đơn</e1> lập <e2>đơn thuốc</e2> và chuyển đơn thuốc đó vào hộp thư kê đơn điện tử quốc gia.
# TRY keep entity mark when tokenize for
# Trong laze hóa học, <e1>sự đảo ngược</e1> được tạo ra bởi một <e2>phản ứng</e2> hóa học.
# TRY keep entity mark when tokenize for
# <e2>Rượu</e2> <e1>nho đỏ</e1> là thức uống trái cây có độ cồn từ 10 đến 14%.
# TRY keep entity mark when tokenize for
# Lisa rất <e1>niềm vui</e1> khi <e2>cười</e2>, tình nguyện ở trường, chụp ảnh, trò chuyện, Twins và Vikings, chơi bóng mềm và bóng chuyền, và thời gian ở Hồ Vermilion.
# TRY keep entity mark when tokenize for
# Bài báo đã thực hiện rất tốt việc ràng buộc ba <e1>trường hợp</e1> theo thủ tục từ <e2>nhiệm kỳ</e2> trước với các vấn đề kiện tụng phức tạp hơn.
# TRY keep entity mark when tokenize for
# <e1>ô tô</e1> của đối thủ đã đạt được mức tiết kiệm nhiên liệu cao nhất khi sử dụng một <e2>động cơ</e2> đốt trong nhỏ.
# TRY keep entity mark when tokenize for
# Những người làm vườn này đã thổi <e1>những chiếc lá</e1> xuống <e2>đường phố</e2>.
# TRY keep entity mark when tokenize for
# <e1>Đá</e1> <e2>mài</e2> làm phẳng đế trượt tuyết, loại bỏ vật liệu nền bị cháy và hư hỏng, đồng thời cung cấp cấu trúc vi mô quan trọng.
# TRY keep entity mark when tokenize for
# Anh ấy là <e1>người chơi</e1> bass đôi độc tấu trong một <e2>dàn nhạc</e2> giao hưởng; vào thời điểm đó, điều đó gần như là không thể vì lý do phân biệt chủng tộc.
# TRY keep entity mark when tokenize for
# Nhưng ngay cả khi sốt ruột mò mẫm tìm <e1>công tắc</e1> của <e2>đèn</e2> điện, cô biết rằng giọng nói đó không phát ra từ chiếc giường ở phía bên kia của căn phòng.
# TRY keep entity mark when tokenize for
# Tôi có một <e1>cuộn băng</e1> từ năm 1969 nằm trong một <e2>hộp</e2> với nhiều bản sao khác nhau của Ngày hôm qua và Hôm nay, một số có hình ảnh giả của Fabs đang cầm thịt.
# TRY keep entity mark when tokenize for
# Con <e1>con lợn</e1> nằm trong <e2>thùng</e2> phía sau xe, lạnh cóng, anh Huy lội xuống xe cho nó ăn tối hôm đó và sáng hôm sau.
# TRY keep entity mark when tokenize for
# <e1>Phim</e1> tài liệu này tiết lộ cái nhìn sâu sắc gây sốc về <e2>nền kinh tế</e2> và cuộc sống hàng ngày của người Jamaica.
# TRY keep entity mark when tokenize for
# Trong loạt phim Robin Hood năm 2006, Robin đã có lúc bị hạ xuống <e1>hố</e1> toàn <e2>rắn</e2> độc.
# TRY keep entity mark when tokenize for
# Tuy nhiên, một số <e1>vấn đề</e1> đã được chỉ ra trong quá trình <e2>nghiên cứu</e2> khả thi này.
# TRY keep entity mark when tokenize for
# Các nhà tài trợ cá nhân tạo ra sự khác biệt đáng kể trong việc giải quyết <e1>đau khổ</e1> do <e2>khủng hoảng</e2> kinh tế gây ra.
# TRY keep entity mark when tokenize for
# Những <e1>việc nhập môn</e1> này chỉ được truyền cho một số ít người được chọn sau <e2>năm</e2> học nghề.
# TRY keep entity mark when tokenize for
# Hiệu trưởng dọa rút <e1>tiền</e1> từ <e2>tờ báo</e2> của học sinh vì đã đưa tin về việc đốt cờ.
# TRY keep entity mark when tokenize for
# <e1>đại não</e1> (não trước) được tạo thành từ <e2>bán cầu</e2> não phải và trái.
# TRY keep entity mark when tokenize for
# Vô tình, <e1>điều khiển từ xa</e1> của tôi rơi xuống <e2>nước</e2>.
# TRY keep entity mark when tokenize for
# Dự án Kho lưu trữ cộng đồng của Dickens đánh dấu kỷ niệm hai trăm năm ngày <e2>ngày sinh</e2> của <e1>tác giả</e1>.
# TRY keep entity mark when tokenize for
# Tôi thấy từ Luân Đôn, ngay cả khi có sự hiện diện của hoàng tử, một <e1>đám đông</e1> vĩ đại gồm những người <e2>người</e2> hèn hạ và nhẹ dạ.
# TRY keep entity mark when tokenize for
# <e1>Cơn bão</e1> tuyết vào cuối tuần đã gây ra <e2>hủy bỏ</e2> trận đấu theo lịch trình của Tornadoes.
# TRY keep entity mark when tokenize for
# Tác động biến đổi khí hậu của cà phê cappuccino phụ thuộc vào việc quán cà phê có kính hai lớp hay không, các quyết định mà nhân viên và tôi đưa ra để đạt được điều đó, chế độ ăn uống của <e1>con bò</e1> sản xuất khí mê-tan tạo ra <e2>sữa</ e2> và nguồn điện cho máy pha cà phê espresso.
# SKIP for
# Tác động biến đổi khí hậu của cà phê cappuccino phụ thuộc vào việc quán cà phê có kính hai lớp hay không, các quyết định mà nhân viên và tôi đưa ra để đạt được điều đó, chế độ ăn uống của <e1>con bò</e1> sản xuất khí mê-tan tạo ra <e2>sữa</ e2> và nguồn điện cho máy pha cà phê espresso.
# TRY keep entity mark when tokenize for
# Người <e1>người trồng trọt</e1> phải lật cánh đồng cày bằng <e2>moldboard</e2> đã sửa đổi.
# TRY keep entity mark when tokenize for
# Giám đốc điều hành của Bottega Veneta, nhà <e1>nhà sản xuất</e1> những chiếc <e2>túi xách</e2> dệt đặc biệt và nổi tiếng của Ý, đang lên kế hoạch cho điều tồi tệ nhất trong khi hy vọng điều gì đó tốt hơn.
# TRY keep entity mark when tokenize for
# Các thành viên chủ yếu quan tâm đến <e1>các vấn đề</e1> liên quan đến <e2>luật</e2> gia đình.
# TRY keep entity mark when tokenize for
# Tôi bị <e1>thương tích</e1> do sơ suất của <e2>người</e2> khác gây ra và tôi đã nộp đơn yêu cầu bồi thường thương tích.
# TRY keep entity mark when tokenize for
# Chúng tôi mô tả thiết kế và tổng hợp <e1>tinh thể</e1> lỏng sắt điện bao gồm các <e2>phân tử</e2> raxemic.
# TRY keep entity mark when tokenize for
# Hôm nọ, tôi đang ngồi trong phòng khách sạn và tìm thấy <e1>kinh thánh</e1> trong <e2>ngăn bàn</e2>, tôi nhận được một vài câu trích dẫn có vẻ hay và bày tỏ cảm xúc của mình.
# TRY keep entity mark when tokenize for
# Trong sáu năm, câu lạc bộ này đã quyên góp một <e1>số tiền</e1> lớn cho các <e2>tổ chức từ thiện</e2> dành cho trẻ em địa phương và các gia đình.
# TRY keep entity mark when tokenize for
# <e1>Đá</e1> <e2>mài</e2> rất kỹ thuật.
# TRY keep entity mark when tokenize for
# Loại thuế được đề xuất đã giúp đẩy <e1>ứng cử viên</e1> vào <e2>cuộc đua</e2> vào Thượng viện.
# TRY keep entity mark when tokenize for
# Khi <e1>lực</e1> được tạo thông qua <e2>cần điều khiển</e2>, lực được tái tạo khớp với lực ban đầu chính xác hơn nhiều.
# TRY keep entity mark when tokenize for
# Nhu cầu về <e1>dầu cọ</e1> <e2>dầu</e2>, một loại dầu thực vật có trong nhiều hàng hóa chúng ta mua, đang góp phần phá hủy khu rừng nhiệt đới quý giá nhất thế giới.
# TRY keep entity mark when tokenize for
# Một <e1>cô bé</e1> nhỏ tìm thấy chiếc giày bị mất với sự giúp đỡ của <e2>người bạn đồng hành</e2> khủng long tưởng tượng của mình.
# TRY keep entity mark when tokenize for
# Berserk là một tiêu đề trong ký ức gần đây đã thực hiện một công việc đáng ngưỡng mộ là ném ra một <e1>vườn thú</e1> thực sự gồm <e2>quỷ</e2>, côn đồ, ác quỷ, quái vật và sinh vật hôi thối trước mắt người đọc trong mỗi tập, mời gọi sự kinh ngạc về sự sáng tạo và kỹ năng liên quan đến việc hình thành và thực hiện loài sâu bọ ghê tởm như vậy.
# TRY keep entity mark when tokenize for
# <e1>cuộc triển lãm</e1> trưng bày <e2>quan điểm</e2> lịch sử về quá trình phát triển trò chơi điện tử từ những trò chơi điện tử thùng đầu tiên cho đến nay.
# TRY keep entity mark when tokenize for
# <e1>acetoin</e1> lần đầu tiên được chưng cất từ ​​<e2>dịch lọc</e2> và sau đó được oxy hóa thành biacetyl.
# TRY keep entity mark when tokenize for
# Rất nhiều người đang chụp ảnh tại <e1>bó hoa</e1> lớn <e2>hoa</e2> màu vàng ở Showa Kinen.
# TRY keep entity mark when tokenize for
# Ong chúa gửi từng quả trứng vào <e1>ô</e1> do <e2>ong</e2> thợ chuẩn bị.
# TRY keep entity mark when tokenize for
# Trình tạo chủ nghĩa hậu hiện đại được viết bởi Andrew C. Bulhak bằng cách sử dụng Công cụ Dada, một hệ thống tạo <e1>văn bản</e1> ngẫu nhiên từ <e2>ngữ pháp</e2> đệ quy.
# TRY keep entity mark when tokenize for
# Tôi đã đăng <e1>sản phẩm</e1> lên <e2>ngôi nhà</e2> của bạn vào thứ Sáu tuần trước.
# TRY keep entity mark when tokenize for
# Rùa biển và <e1>sư tử</e1> biển sử dụng <e2>chân chèo</e2> phía trước để di chuyển về phía trước.
# TRY keep entity mark when tokenize for
# <e1>Thợ đóng ván</e1> làm việc bằng cách đẽo hoặc tiện các mảnh gỗ thành <e2>hình dạng</e2> cần thiết cho sản phẩm cuối cùng, đặc biệt là bánh xe.
# TRY keep entity mark when tokenize for
# Khi mới sinh, <e1>bệnh nhân</e1> có <e2>lỗ mũi</e2> thừa hai bên, nằm phía trên lỗ mũi bình thường và mở vào khoang mũi cùng bên.

# %%
! python3 method1_encode_features.py
# Out:
# 2023-12-01 06:09:18.811771: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 06:09:18.811880: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 06:09:18.811932: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 06:09:20.245772: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# config.json: 100% 678/678 [00:00<00:00, 2.57MB/s]
# vocab.txt: 100% 895k/895k [00:00<00:00, 12.7MB/s]
# bpe.codes: 100% 1.14M/1.14M [00:00<00:00, 36.0MB/s]
# tokenizer.json: 100% 3.13M/3.13M [00:00<00:00, 43.3MB/s]

# %%
# ! python3 method1_phobert_sentences_embeding.py

# %%
! python3 method2_encode_features.py
# Out:
# 2023-12-01 08:40:30.574686: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-01 08:40:30.574761: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-01 08:40:30.574796: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-01 08:40:32.139374: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [['pob', 'nmod', 'nmod', 'pob'], ['sub', 'vmod', 'coord', 'conj', 'vmod', 'pob'], ['nmod', 'pob', 'nmod', 'vmod'], ['sub', 'loc', 'pob'], ['sub', 'nmod'], ['vmod', 'nmod', 'amod'], ['nmod', 'prp', 'vmod'], ['det', 'sub', 'dob'], ['sub', 'vmod', 'loc', 'pob'], ['vmod', 'vmod', 'vmod', 'dob', 'nmod'], ['sub', 'vmod', 'tmp', 'pob'], ['sub', 'loc', 'pob'], ['dob', 'vmod', 'dob'], ['sub', 'nmod'], ['sub', 'vmod'], ['dob', 'prp', 'vmod', 'vmod', 'pob'], ['sub', 'vmod', 'dob', 'nmod', 'pob'], ['pob', 'nmod', 'vmod', 'nmod', 'amod', 'nmod'], ['nmod', 'dob', 'nmod'], ['pob', 'nmod', 'nmod'], ['sub', 'tmp', 'pob'], ['dob', 'nmod', 'dob'], ['sub', 'dob', 'nmod', 'vmod'], ['nmod', 'sub', 'prp', 'vmod', 'vmod', 'nmod'], ['pob', 'nmod', 'pob'], ['sub', 'vmod', 'mnr', 'pob'], ['sub', 'dob', 'pmod', 'pob', 'nmod', 'dob'], ['sub', 'dob', 'nmod', 'pob'], ['dob', 'nmod', 'vmod', 'iob', 'pob'], ['sub', 'nmod', 'dob', 'nmod', 'pob'], ['dob', 'nmod', 'pob'], ['conj', 'coord', 'vmod', 'prp', 'dep', 'sub'], ['pob', 'nmod', 'pob'], ['dob', 'nmod', 'dob', 'nmod', 'loc', 'pob'], ['pob', 'nmod', 'pob'], ['dob', 'conj', 'coord', 'vmod', 'coord', 'tmp', 'pob'], ['sub', 'vmod', 'dob', 'nmod'], ['sub', 'vmod', 'vmod', 'dob'], ['sub', 'dob', 'pmod', 'pob', 'nmod', 'vmod', 'pob'], ['sub', 'mnr', 'pob', 'nmod', 'pob', 'nmod', 'pob'], ['sub', 'dob'], ['sub', 'nmod', 'loc', 'nmod', 'nmod', 'nmod'], ['vmod', 'nmod'], ['sub', 'vmod', 'loc'], ['sub', 'prp', 'dep'], ['sub', 'nmod', 'dob'], ['sub', 'vmod', 'dob'], ['pob', 'nmod', 'pob', 'loc', 'prp', 'dep', 'sub'], ['pob', 'loc', 'vmod', 'vmod'], ['nmod', 'nmod'], ['sub', 'nmod', 'pob', 'nmod', 'vmod'], ['sub', 'nmod'], ['vmod', 'prp', 'dep', 'sub'], ['nmod', 'nmod'], ['conj', 'nmod'], ['dob', 'nmod', 'nmod'], ['nmod', 'dob', 'coord'], ['vmod', 'pob'], ['sub', 'vmod', 'pob', 'loc', 'pob', 'nmod', 'loc', 'pob'], ['nmod', 'vmod', 'pob'], ['sub', 'loc', 'pob'], ['conj', 'coord', 'nmod', 'nmod', 'pob', 'mnr', 'nmod', 'pob', 'nmod', 'loc', 'pob'], ['sub', 'nmod', 'dob'], ['dob', 'nmod', 'loc', 'pob'], ['nmod', 'sub', 'dep', 'vmod', 'loc', 'pob', 'nmod', 'vmod'], ['conj', 'coord', 'dob', 'nmod', 'pob'], ['sub', 'nmod', 'dob'], ['sub', 'dob'], ['dob', 'loc', 'pob'], ['sub', 'nmod', 'prp', 'dep', 'sub'], ['sub', 'vmod', 'vmod', 'nmod', 'prp', 'dep', 'sub'], ['dob', 'nmod', 'dob'], ['sub', 'prp', 'dep', 'sub'], ['sub', 'vmod', 'dir', 'pob'], ['sub', 'vmod', 'dob'], ['sub', 'nmod', 'dep', 'sub', 'det'], ['nmod', 'sub', 'vmod', 'vmod', 'pob'], ['sub', 'vmod', 'mnr', 'pob', 'nmod', 'dob'], ['nmod', 'amod', 'nmod', 'pob', 'adv', 'sub'], ['prp', 'vmod'], ['dob', 'nmod', 'dob'], ['det', 'pob'], ['sub', 'dob', 'nmod', 'vmod'], ['dob', 'nmod', 'dob', 'det'], ['det', 'pob', 'nmod', 'vmod', 'prp', 'pob'], ['pob', 'nmod', 'pob'], ['sub', 'vmod', 'dir', 'pob'], ['pob', 'nmod', 'nmod', 'pob', 'tmp', 'nmod'], ['pob', 'nmod', 'dep', 'dob', 'nmod', 'dob'], ['sub', 'vmod', 'vmod', 'pob'], ['sub', 'iob', 'vmod', 'vmod', 'dob'], ['sub', 'loc', 'pob'], ['sub', 'vmod', 'vmod', 'pob'], ['sub', 'dob', 'loc', 'pob'], ['prd', 'amod', 'nmod', 'loc', 'pob'], ['sub', 'dob', 'nmod', 'mnr', 'pob'], ['conj', 'nmod', 'dob', 'det'], ['prp', 'pob'], ['nmod', 'pob', 'mnr', 'vmod', 'vmod', 'vmod', 'prp', 'pob'], ['dob', 'vmod', 'vmod', 'prp', 'dep', 'sub'], ['dob', 'dob'], ['sub', 'nmod', 'dep', 'sub'], ['sub', 'nmod', 'dob'], ['sub', 'conj', 'prp', 'vmod'], ['conj', 'loc', 'pob'], ['dob', 'nmod', 'pob', 'det'], ['dob', 'vmod', 'vmod', 'adv'], ['sub', 'vmod', 'dir', 'pob'], ['sub', 'vmod', 'loc', 'pob'], ['pob', 'loc', 'conj', 'coord', 'conj', 'vmod', 'loc', 'pob'], ['nmod', 'pob', 'nmod', 'vmod', 'loc', 'pob'], ['vmod', 'loc', 'nmod', 'sub'], ['sub', 'nmod'], ['dob', 'nmod'], ['nmod', 'dob', 'nmod'], ['loc', 'pob', 'nmod', 'dob'], ['pob', 'nmod'], ['pob', 'nmod', 'conj', 'loc', 'pob', 'nmod'], ['sub', 'nmod'], ['sub', 'dob', 'nmod', 'pob'], ['pob', 'nmod', 'loc', 'pob'], ['det', 'sub', 'loc', 'pob'], ['pob', 'nmod', 'vmod', 'tmp', 'pob', 'nmod', 'vmod', 'pob'], ...
# [[5, 7, 7, 5], [12, 10, 4, 6, 10, 5], [7, 5, 7, 10], [12, 1, 5], [12, 7], [10, 7, 20], [7, 8, 10], [14, 12, 19], [12, 10, 1, 5], [10, 10, 10, 19, 7], [12, 10, 13, 5], [12, 1, 5], [19, 10, 19], [12, 7], [12, 10], [19, 8, 10, 10, 5], [12, 10, 19, 7, 5], [5, 7, 10, 7, 20, 7], [7, 19, 7], [5, 7, 7], [12, 13, 5], [19, 7, 19], [12, 19, 7, 10], [7, 12, 8, 10, 10, 7], [5, 7, 5], [12, 10, 15, 5], [12, 19, 16, 5, 7, 19], [12, 19, 7, 5], [19, 7, 10, 9, 5], [12, 7, 19, 7, 5], [19, 7, 5], [6, 4, 10, 8, 21, 12], [5, 7, 5], [19, 7, 19, 7, 1, 5], [5, 7, 5], [19, 6, 4, 10, 4, 13, 5], [12, 10, 19, 7], [12, 10, 10, 19], [12, 19, 16, 5, 7, 10, 5], [12, 15, 5, 7, 5, 7, 5], [12, 19], [12, 7, 1, 7, 7, 7], [10, 7], [12, 10, 1], [12, 8, 21], [12, 7, 19], [12, 10, 19], [5, 7, 5, 1, 8, 21, 12], [5, 1, 10, 10], [7, 7], [12, 7, 5, 7, 10], [12, 7], [10, 8, 21, 12], [7, 7], [6, 7], [19, 7, 7], [7, 19, 4], [10, 5], [12, 10, 5, 1, 5, 7, 1, 5], [7, 10, 5], [12, 1, 5], [6, 4, 7, 7, 5, 15, 7, 5, 7, 1, 5], [12, 7, 19], [19, 7, 1, 5], [7, 12, 21, 10, 1, 5, 7, 10], [6, 4, 19, 7, 5], [12, 7, 19], [12, 19], [19, 1, 5], [12, 7, 8, 21, 12], [12, 10, 10, 7, 8, 21, 12], [19, 7, 19], [12, 8, 21, 12], [12, 10, 2, 5], [12, 10, 19], [12, 7, 21, 12, 14], [7, 12, 10, 10, 5], [12, 10, 15, 5, 7, 19], [7, 20, 7, 5, 22, 12], [8, 10], [19, 7, 19], [14, 5], [12, 19, 7, 10], [19, 7, 19, 14], [14, 5, 7, 10, 8, 5], [5, 7, 5], [12, 10, 2, 5], [5, 7, 7, 5, 13, 7], [5, 7, 21, 19, 7, 19], [12, 10, 10, 5], [12, 9, 10, 10, 19], [12, 1, 5], [12, 10, 10, 5], [12, 19, 1, 5], [3, 20, 7, 1, 5], [12, 19, 7, 15, 5], [6, 7, 19, 14], [8, 5], [7, 5, 15, 10, 10, 10, 8, 5], [19, 10, 10, 8, 21, 12], [19, 19], [12, 7, 21, 12], [12, 7, 19], [12, 6, 8, 10], [6, 1, 5], [19, 7, 5, 14], [19, 10, 10, 22], [12, 10, 2, 5], [12, 10, 1, 5], [5, 1, 6, 4, 6, 10, 1, 5], [7, 5, 7, 10, 1, 5], [10, 1, 7, 12], [12, 7], [19, 7], [7, 19, 7], [1, 5, 7, 19], [5, 7], [5, 7, 6, 1, 5, 7], [12, 7], [12, 19, 7, 5], [5, 7, 1, 5], [14, 12, 1, 5], [5, 7, 10, 13, 5, 7, 10, 5], [12, 10, 1, 5], [12, 10, 10, 20, 7, 15, 5], [19, 7, 10], [19, 1, 5], [7, 12, 19], [12, 10, 2, 5], [12, 1, 5], [12, 7, 5], [7, 7, 19], [14, 12, 10, 1, 5], [19, 7, 5], [12, 2, 5], [19, 1, 5], [12, 7, 19], [7, 8, 21, 2, 5], [19, 7, 5], [12, 7], [12, 6, 4, 10], [10, 7], [20, 7, 8, 21, 12], [7, 13, 7, 5, 14], [12, 7], [19, 1, 5], [19, 10, 9, 5], [7, 12, 10, 10, 10, 1, 7], [7, 12, 13, 5], [12, 10, 10, 5], [14, 12, 19, 14], [12, 7], [12, 10, 1, 5], [12, 1, 5], [10, 5, 7], [5, 7, 10, 5], [10, 10, 5], [5, 7], [19, 10, 10, 8, 10, 19], [12, 19, 15, 5], [12, 19], [12, 19, 7, 5], [12, 8, 21], [10, 1, 5], [10, 1, 5], [19, 7], [19, 13, 7, 10, 5], [19, 13, 5, 7], [6, 4, 5, 7, 5, 10, 7, 13, 10, 10, 19], [19, 7, 8, 10, 15, 5], [7, 12, 7], [12, 19], [19, 10, 13, 19], [7, 5, 2, 10, 8, 10, 1, 5], [19, 1, 5], [7, 7, 10, 7, 15, 5], [12, 19], [5, 7, 8, 5], [5, 7, 5], [14, 19, 1, 5], [19, 10, 10], [7, 5, 7, 5], [12, 7, 5], [20, 7, 19], [12, 7, 15, 5], [12, 1, 5], [19, 7, 19], [12, 1, 5], [6, 4, 19, 7, 10, 1, 7, 7, 5], [19, 7, 19, 10, 19], [19, 1, 5], [19, 7, 5], [19, 7, 10], [14, 19, 7, 5], [5, 7, 21, 12], [5, 7, 5], [12, 7, 10, 10, 5], [12, 19, 7, 5], [12, 10, 5], [12, 19, 7], [5, 7, 5, 7, 7, 12], [12, 1, 5, 7], [19, 8, 21, 12], [19, 7, 5], [7, 12, 19], [19, 10, 13, 5], [19, 10, 1], [6, 7], [7, 19], [10, 7, 5, 7], [7, 5, 7], [12, 8, 21, 6, 5], [12, 1, 5], [12, 10, 10, 5], [14, 12, 19], [10, 10, 19], [14, 12, 4, 6, 15, 10], [], [19, 7, 5], [8, 5], [12, 10, 10, 5, 7], [5, 7, 5], [12, 10, 10, 19], [19, 7, 5], [12, 7, 15, 5], [7, 19, 7, 5], [14, 7, 7, 14], [12, 10, 1, 5], [5, 7, 10], [19, 10, 5], [14, 7, 12, 21, 19], [12, 19], [7, 19, 7, 5], [19, 10, 5], [12, 19], [12, 1, 5], [12, 10, 1, 5], [12, 6, 10, 8, 10, 19], [19, 7], [19, 7], [19, 1, 5, 7, 19], [12, 21, 10, 1, 5], [12, 10, 1, 5], [12, 10, 8, 5], [12, 10, 10, 10, 1, 5], [12, 10, 5], [7, 10, 5, 7], [12, 10, 10, 14], [12, 1, 5], [12, 10, 19], [12, 19], [10, 10, 10, 13, 5], [14, 6, 7], [12, 10, 2, 5], [12, 10, 10, 5], [12, 10], [12, 15, ...
# [['sub', 'vmod', 'pob'], ['nmod', 'dob'], ['nmod', 'pob', 'nmod', 'mnr', 'pob'], ['dob', 'vmod', 'nmod', 'sub', 'loc', 'pob'], ['sub', 'dob', 'prp', 'dep', 'sub', 'nmod'], ['sub', 'nmod', 'pob'], ['sub', 'vmod'], ['vmod', 'vmod', 'sub'], ['dob', 'nmod', 'nmod', 'nmod'], ['sub', 'dob'], ['sub', 'loc', 'pob', 'det'], ['dob', 'nmod', 'dob'], ['dob', 'loc', 'pob'], ['dob', 'loc'], ['dob', 'nmod', 'loc', 'pob'], ['dob', 'nmod', 'dob', 'vmod', 'loc'], ['sub', 'loc'], ['vmod', 'vmod', 'mnr', 'pob'], ['dob', 'nmod', 'vmod'], ['sub', 'vmod', 'vmod', 'pob'], ['sub', 'loc', 'pob'], ['sub', 'loc', 'pob'], ['nmod', 'pob', 'vmod', 'nmod', 'tmp', 'prp'], ['sub', 'coord', 'conj'], ['sub', 'nmod', 'dob'], ['pob', 'loc', 'pob'], ['sub', 'vmod', 'pob'], ['dob', 'nmod', 'tmp', 'vmod', 'vmod', 'pob'], ['det', 'dob', 'coord', 'conj', 'loc', 'pob', 'det'], ['pob', 'nmod', 'dob', 'tmp', 'pob'], ['nmod', 'nmod', 'pob', 'loc', 'dob', 'nmod', 'vmod'], ['sub', 'coord', 'conj', 'vmod', 'pob', 'det'], ['dob', 'nmod', 'pob'], ['amod', 'dep', 'adv', 'sub', 'amod', 'sub'], ['dob', 'nmod', 'pob'], ['sub', 'nmod', 'vmod', 'nmod', 'dob', 'coord', 'conj'], ['pob', 'loc', 'nmod', 'nmod', 'pob', 'nmod', 'det'], ['sub', 'vmod', 'vmod', 'vmod', 'tmp', 'nmod', 'dob'], ['sub', 'nmod', 'nmod'], ['prp', 'dep', 'sub'], ['sub', 'dob', 'nmod', 'pob'], ['sub', 'dob', 'nmod', 'pob'], ['nmod', 'dob'], ['dob', 'loc', 'pob'], ['nmod', 'sub', 'loc', 'pob'], ['sub', 'vmod', 'loc', 'pob'], ['dob', 'nmod', 'pob', 'mnr', 'pmod', 'pob'], ['nmod', 'sub', 'vmod', 'loc', 'nmod'], ['det', 'sub', 'vmod', 'pob'], ['nmod', 'vmod'], ['dob', 'loc', 'pob'], ['sub', 'amod', 'det'], ['det', 'nmod', 'pob', 'det'], ['pob', 'nmod', 'dob'], ['det', 'nmod', 'pob', 'loc', 'dob', 'nmod', 'pob', 'pmod', 'dob', 'nmod', 'loc', 'pmod', 'vmod'], ['nmod', 'sub', 'nmod', 'dob'], ['dob', 'vmod', 'dob'], ['nmod', 'sub', 'vmod'], ['dob', 'nmod'], ['dob', 'nmod'], ['dep'], ['pob', 'nmod', 'pob'], ['sub', 'dob', 'mnr', 'pob', 'nmod', 'dob'], ['sub', 'dob', 'nmod', 'amod', 'vmod'], ['dob', 'loc', 'pob'], ['sub', 'dob'], ['sub', 'nmod', 'dob'], ['sub', 'dob'], ['pob', 'nmod', 'dob', 'nmod', 'vmod', 'nmod'], ['vmod', 'vmod', 'prp', 'pob'], ['pob', 'nmod', 'pob'], ['nmod', 'sub', 'vmod', 'vmod', 'pob'], ['sub', 'vmod', 'prp', 'pob'], ['sub', 'dep', 'dob'], ['nmod', 'pob', 'nmod', 'dob'], ['dob', 'nmod', 'pob'], ['det', 'sub'], ['sub', 'conj', 'mnr', 'pob'], ['dob', 'prp', 'dep', 'sub'], ['sub', 'prp', 'vmod', 'dob'], ['sub', 'nmod', 'pob'], ['sub', 'nmod', 'pob'], ['vmod', 'vmod', 'nmod', 'adv', 'vmod'], ['nmod', 'dob', 'nmod', 'pob'], ['sub', 'vmod', 'prp', 'vmod', 'iob', 'pob', 'nmod', 'vmod', 'pob', 'nmod', 'vmod', 'nmod', 'pob'], ['sub', 'dob', 'nmod', 'nmod'], ['sub', 'dob'], ['sub', 'dob', 'mnr', 'pob', 'nmod'], ['pob', 'nmod'], ['sub', 'dob'], ['sub', 'vmod', 'dob'], ['sub', 'vmod', 'tmp', 'pob'], ['dob', 'nmod', 'vmod', 'vmod', 'nmod', 'pob'], ['sub', 'loc', 'pob'], ['dob', 'nmod', 'vmod'], ['sub', 'vmod', 'loc', 'pob', 'nmod'], ['pob', 'nmod', 'sub', 'vmod'], ['sub', 'nmod', 'pob'], ['sub', 'vmod', 'vmod', 'vmod', 'pob'], ['dob', 'conj', 'vmod', 'pob', 'coord', 'conj'], ['sub', 'dob'], ['sub', 'dob'], ['det', 'dob', 'nmod', 'dob'], ['pob', 'nmod', 'sub', 'dob'], ['pob', 'prp', 'dep', 'sub'], ['vmod', 'loc', 'pob'], ['sub', 'prp', 'dep', 'sub'], ['conj', 'coord', 'conj', 'vmod'], ['pob', 'nmod'], ['pob', 'nmod', 'pob', 'nmod'], ['vmod', 'nmod', 'prp', 'vmod', 'dob', 'coord', 'conj'], ['sub', 'vmod', 'loc', 'pob'], ['sub', 'vmod', 'prp', 'dob'], ['pob', 'nmod', 'sub', 'dob'], ['sub', 'amod'], ['nmod', 'nmod'], ['det', 'nmod', 'pob', 'nmod', 'pob'], ['sub', 'dob'], ['nmod', 'sub', 'nmod', 'dob'], ['sub', 'nmod', 'vmod'], ['dob', 'loc', 'pob'], ['sub', 'nmod', 'dob', 'nmod', 'pob'], ['sub', 'loc', 'pob', 'nmod'], ['conj', 'loc', 'pob'], ['sub', 'dob'], ['pob', 'nmod'], ['sub', 'nmod', 'dob'], ['sub', 'mnr', 'pob'], ['sub', 'nmod', 'dob'], ['sub', 'loc', 'pob'], [], ['dob', 'nmod', 'vmod', 'pob'], ['conj', 'sub', ' ...
# [[12, 10, 5], [7, 19], [7, 5, 7, 15, 5], [19, 10, 7, 12, 1, 5], [12, 19, 8, 21, 12, 7], [12, 7, 5], [12, 10], [10, 10, 12], [19, 7, 7, 7], [12, 19], [12, 1, 5, 14], [19, 7, 19], [19, 1, 5], [19, 1], [19, 7, 1, 5], [19, 7, 19, 10, 1], [12, 1], [10, 10, 15, 5], [19, 7, 10], [12, 10, 10, 5], [12, 1, 5], [12, 1, 5], [7, 5, 10, 7, 13, 8], [12, 4, 6], [12, 7, 19], [5, 1, 5], [12, 10, 5], [19, 7, 13, 10, 10, 5], [14, 19, 4, 6, 1, 5, 14], [5, 7, 19, 13, 5], [7, 7, 5, 1, 19, 7, 10], [12, 4, 6, 10, 5, 14], [19, 7, 5], [20, 21, 22, 12, 20, 12], [19, 7, 5], [12, 7, 10, 7, 19, 4, 6], [5, 1, 7, 7, 5, 7, 14], [12, 10, 10, 10, 13, 7, 19], [12, 7, 7], [8, 21, 12], [12, 19, 7, 5], [12, 19, 7, 5], [7, 19], [19, 1, 5], [7, 12, 1, 5], [12, 10, 1, 5], [19, 7, 5, 15, 16, 5], [7, 12, 10, 1, 7], [14, 12, 10, 5], [7, 10], [19, 1, 5], [12, 20, 14], [14, 7, 5, 14], [5, 7, 19], [14, 7, 5, 1, 19, 7, 5, 16, 19, 7, 1, 16, 10], [7, 12, 7, 19], [19, 10, 19], [7, 12, 10], [19, 7], [19, 7], [21], [5, 7, 5], [12, 19, 15, 5, 7, 19], [12, 19, 7, 20, 10], [19, 1, 5], [12, 19], [12, 7, 19], [12, 19], [5, 7, 19, 7, 10, 7], [10, 10, 8, 5], [5, 7, 5], [7, 12, 10, 10, 5], [12, 10, 8, 5], [12, 21, 19], [7, 5, 7, 19], [19, 7, 5], [14, 12], [12, 6, 15, 5], [19, 8, 21, 12], [12, 8, 10, 19], [12, 7, 5], [12, 7, 5], [10, 10, 7, 22, 10], [7, 19, 7, 5], [12, 10, 8, 10, 9, 5, 7, 10, 5, 7, 10, 7, 5], [12, 19, 7, 7], [12, 19], [12, 19, 15, 5, 7], [5, 7], [12, 19], [12, 10, 19], [12, 10, 13, 5], [19, 7, 10, 10, 7, 5], [12, 1, 5], [19, 7, 10], [12, 10, 1, 5, 7], [5, 7, 12, 10], [12, 7, 5], [12, 10, 10, 10, 5], [19, 6, 10, 5, 4, 6], [12, 19], [12, 19], [14, 19, 7, 19], [5, 7, 12, 19], [5, 8, 21, 12], [10, 1, 5], [12, 8, 21, 12], [6, 4, 6, 10], [5, 7], [5, 7, 5, 7], [10, 7, 8, 10, 19, 4, 6], [12, 10, 1, 5], [12, 10, 8, 19], [5, 7, 12, 19], [12, 20], [7, 7], [14, 7, 5, 7, 5], [12, 19], [7, 12, 7, 19], [12, 7, 10], [19, 1, 5], [12, 7, 19, 7, 5], [12, 1, 5, 7], [6, 1, 5], [12, 19], [5, 7], [12, 7, 19], [12, 15, 5], [12, 7, 19], [12, 1, 5], [], [19, 7, 10, 5], [6, 12, 7, 5], [12, 10, 19], [12, 19, 7, 10, 10, 1, 5], [14, 15, 5, 7, 7, 19, 7, 14], [12, 7, 5], [5, 20, 10, 10], [7, 13, 5], [5, 7, 5], [12, 7, 19], [5, 7, 19, 7, 13, 5], [19, 1, 5], [12, 8], [19, 7], [14, 12, 19], [14, 12, 1, 5], [14, 12, 10, 15, 5], [12, 19, 7, 19], [6, 10, 19], [10, 10, 5], [19, 7, 13, 7, 19], [19, 7], [12, 7, 10, 5], [12, 19], [19, 7, 19, 10, 8, 19], [19, 7, 5], [12, 19, 7, 5], [6, 7, 19], [14, 12, 10, 1, 5], [12, 10, 5], [12, 10, 10, 5], [12, 4], [14, 12, 19], [12, 10, 1, 5], [19, 7, 10, 1, 7], [19, 7, 5], [5, 1, 10, 1, 5, 7, 5, 7, 10], [7, 6, 4, 12, 19, 7, 10, 1, 5], [12, 10, 19, 7, 10, 15, 5, 7, 19], [12, 1, 5, 14], [19, 7, 5], [12, 19, 7, 5, 7], [12, 19, 16, 5, 7, 5], [10, 13, 5], [19, 10, 7, 13, 12], [12, 10, 2, 5], [5, 7, 12, 10, 5, 14], [5, 7, 12, 19, 7, 20, 5, 7, 19], [19, 7, 10, 5], [12, 10, 10, 5, 14], [19, 1, 5], [12, 19], [5, 20, 10, 21, 8, 21, 19], [12, 10, 1, 5], [19, 7, 10], [19, 1, 5], [5, 7, 12], [12, 10, 10, 5], [12, 1, 7, 7, 19, 7, 10, 5, 7], [12, 10], [5, 7, 5, 7, 5], [19, 10, 10, 19, 7], [7, 19], [12, 10, 1, 5], [7, 12, 19], [19, 7], [12, 10, 19], [19, 1, 5], [12, 10, 1, 5], [5, 7, 5], [12, 1, 5], [19, 7, 7, 10], [7, 5, 1, 10, 8, 21, 12], [7], [5, 7, 16, 5, 7], [12, 10, 15, 5], [19, 7, 21, 20], [12, 7, 19], [19, 7, 19, 14], [19, 7, 5], [10, 10, 19], [5, 7, 19, 7, 10, 1, 5], [12, 15, 5], [5, 7], [19, 7, 20], [19, 8, 1, 5, 7], [19, 7, 5], [7, 12, 8, 5], [19, 10, 5], [12, 1, 5], [19, 7, 12, 13, 5], [12, 10, 5], [14, 12, 10, 1, 5], [12, 1, 5], [19, 7, 19, 7, 10, 19], [12, 10, 1, 5, 7, 19], [12, 7, 5], [7, 7, 7, 5, 7, 5], [7, 12, 10, 5], [12, 1, 5], [12, 7], [12, 19], [21, 20], [10, 7, 10], [7, 19, 13, 5], [12, 10, 8, 10], [10, 4, 6, 1, 5], [7, 12, 7, 5, 7, 10], [5, 1, 10, 8, 10], [19, 7, 5], [19, 7, 5, 7, 5], [5, 7, 5], [7, 7], [12, 7, 5], [7, 7, 7], [12, 10, 1, 7], [10, 7, 5, 7, 5], [7, 13, 7, 5, 7, 5], [19, 7, 19, 10, 1, 5, 7, 7], [5, 7, 5], [12, 10, 19], [12, 10, 5], [10, 19, 7, 10, 7, 5], [ ...

# %%
import numpy as np
X_train = np.load('data/X_train_method2.npy')
y_train = np.load('data/y_train_method2.npy')
X_test = np.load('data/X_test_method2.npy')
y_test = np.load('data/y_test_method2.npy')

# %%
X_train.shape
# Out:
# (7, 7981, 12)
